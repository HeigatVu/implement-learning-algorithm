# %%
import cv2
import numpy as np

import seaborn as sns
import random

import math

# %%
img = cv2.imread('Sydney-Opera-House.jpg', 0)
height, width = img.shape

print(height, width)
# Out:
# 360 640

# %%
sns.set_theme()

data = [5, 3, 8, 7, 3, 2, 7, 0, 9]
sns.distplot(data)
# Out:
# /tmp/ipykernel_38628/1911878702.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import random
sns.set_theme()

# load image
img = cv2.imread('Sydney-Opera-House.jpg', 0)
height, width = img.shape

# ...
num_of_samples = 10000
sample_size = 50

means = []
for _ in range(num_of_samples):    
    mean = 0
    for _ in range(sample_size):
        # generate a random point
        x = random.randint(0, height-1) # remove
        y = random.randint(0, width-1)  # remove
        
        # get pixel value and add to mean
        mean = mean + img[x][y]         # remove
    # normalize to get mean
    mean = mean/sample_size
    
    # add to list
    means.append(mean)
# Out:
# /tmp/ipykernel_38628/339756933.py:22: RuntimeWarning: overflow encountered in scalar add
#   mean = mean + img[x][y]         # remove

# %%
plot = sns.distplot(means)
fig = plot.get_figure()
fig.savefig("out.png")
# Out:
# /tmp/ipykernel_38628/2213299712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plot = sns.distplot(means)

# %%
num_of_samples = 10000
sample_size = 30
side = 500

means = []
for _ in range(num_of_samples):    
    mean = 0
    for _ in range(sample_size):
        # generate a random point 
        x = random.randint(0, side-1)  # remove
        y = random.randint(0, side-1)  # remove
        
        # distance to (0,0)
        distance = math.sqrt(x*x + y*y)
        
        # get pixel value and add to mean
        mean = mean + distance         # remove
    # normalize to get mean
    mean = mean/sample_size
    
    # add to list
    means.append(mean)

# %%
sns.set_theme()

sns.distplot(means)
# Out:
# /tmp/ipykernel_38628/1138047549.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(means)
# <Axes: ylabel='Density'>
